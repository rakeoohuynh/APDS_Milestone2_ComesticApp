# %%
import pandas as pd

# %%
df = pd.read_csv('processed.csv')

# %%
group_df = df.groupby('product_title')['product_id']

# %%
group_df = df.drop_duplicates(subset='product_id').reset_index(drop=True)
print(f"Unique products: {len(group_df)}")
group_df.head()

# %%
group_df.unique().count()
# Out:
# np.int64(292)

# %%
group_df.head()
# Out:
# 0         781070
# 1         781070
# 2         781070
# 3         781070
# 4         781070
#           ...
# 61060    1044490
# 61061    1044490
# 61062    1044490
# 61063    1044490
# 61283    4633369
# Name: product_id, Length: 1186, dtype: int64
